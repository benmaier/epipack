# %%
import numpy as np
import epipack as epk
import matplotlib.pyplot as pl
# %matplotlib notebook

# %%
latent_period = 7
infectious_period = 8

omega = 1/latent_period
rho = 1/infectious_period

E0 = 1e-4

R0 = 2

alpha = rho * R0

pdf = lambda t: omega*rho/(omega-rho) * (np.exp(-t*rho) - np.exp(-t*omega))

T = np.linspace(0,60,30)
pl.plot(T, pdf(T))
# Out:
# <img src="data:image/png;base64,..." width="499.9999925494195">

# %%
infcurve = 0.5 * (pdf(T)[1:] + pdf(T)[:-1])

# %%
taus = np.diff(T)
norm = infcurve.dot(taus)
infcurve = infcurve/norm * R0

# %%
pl.step(T[:-1],infcurve,where='post')

# %%
t = np.linspace(0,4000,10001)
default, inf_comps_dflt  = get_default_model()
soph, inf_comps_soph = get_soph_model()

# %%
r_dflt = default.integrate(t)
r_soph = soph.integrate(t)

# %%
r_soph['I'] = sum([ r_soph.pop(I) for I in inf_comps_soph])
r_dflt['I'] = sum([ r_dflt.pop(I) for I in inf_comps_dflt])

# %%
from epipack.plottools import plot

ax = plot(t,r_dflt)
plot(t,r_soph, ax = ax)
ax.set_yscale('log')
# Out:
# <img src="data:image/png;base64,..." width="499.9999925494195">

# %%
taus
# Out:
# array([0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5])
